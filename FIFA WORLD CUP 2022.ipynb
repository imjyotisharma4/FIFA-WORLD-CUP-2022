# %%
# importing libraries

import numpy as np
import pandas as pd
import seaborn as sns

# %%
# loading the data
data=pd.read_csv("fifa_world_cup_2022_tweets.csv")
data
# Out:
#        Unnamed: 0               Date Created  Number of Likes  \
# 0               0  2022-11-20 23:59:21+00:00                4
# 1               1  2022-11-20 23:59:01+00:00                3
# 2               2  2022-11-20 23:58:41+00:00                1
# 3               3  2022-11-20 23:58:33+00:00                1
# 4               4  2022-11-20 23:58:28+00:00                0
# ...           ...                        ...              ...
# 22519       22519  2022-11-20 00:00:21+00:00                1
# 22520       22520  2022-11-20 00:00:03+00:00                0
# 22521       22521  2022-11-20 00:00:01+00:00                2
# 22522       22522  2022-11-20 00:00:00+00:00               11
# 22523       22523  2022-11-20 00:00:00+00:00               24
#
#            Source of Tweet                                              Tweet  \
# 0          Twitter Web App  What are we drinking today @TucanTribe \n@MadB...
# ...

# %%
type(data)         #data type
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()            #top 5 values
# Out:
#    Unnamed: 0               Date Created  Number of Likes  \
# 0           0  2022-11-20 23:59:21+00:00                4
# 1           1  2022-11-20 23:59:01+00:00                3
# 2           2  2022-11-20 23:58:41+00:00                1
# 3           3  2022-11-20 23:58:33+00:00                1
# 4           4  2022-11-20 23:58:28+00:00                0
#
#        Source of Tweet                                              Tweet  \
# 0      Twitter Web App  What are we drinking today @TucanTribe \n@MadB...
# 1   Twitter for iPhone  Amazing @CanadaSoccerEN  #WorldCup2022 launch ...
# 2   Twitter for iPhone  Worth reading while watching #WorldCup2022 htt...
# 3      Twitter Web App  Golden Maknae shinning bright\n\nhttps://t.co/...
# 4  Twitter for Android  If the BBC cares so much about human rights, h...
#
#   Sentiment
# 0   neutral
# 1  positive
# 2  positive
# 3  positive
# 4  negative

# %%
data.tail()
# Out:
#        Unnamed: 0               Date Created  Number of Likes  \
# 22519       22519  2022-11-20 00:00:21+00:00                1
# 22520       22520  2022-11-20 00:00:03+00:00                0
# 22521       22521  2022-11-20 00:00:01+00:00                2
# 22522       22522  2022-11-20 00:00:00+00:00               11
# 22523       22523  2022-11-20 00:00:00+00:00               24
#
#           Source of Tweet                                              Tweet  \
# 22519     Twitter Web App            Here We go World cup 2022 #WorldCup2022
# 22520            DenetPro  Anderlecht confirms former Viborg FF's Jesper ...
# 22521  Twitter for iPhone  Great thread to read before the start of #Worl...
# 22522     Twitter Web App  Raphinha wants Brazil to be united at the #Wor...
# 22523     Twitter Web App  How to buy $SOT on PinkSale?🤔\n\nHave you been...
#
#       Sentiment
# 22519  positive
# 22520   neutral
# 22521  positive
# 22522  positive
# 22523   neutral

# %%
data.shape                 #to check the dimensions of data
# Out:
# (22524, 6)

# %%
data.info()                         #preview of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22524 entries, 0 to 22523
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       22524 non-null  int64
#  1   Date Created     22524 non-null  object
#  2   Number of Likes  22524 non-null  int64
#  3   Source of Tweet  22524 non-null  object
#  4   Tweet            22524 non-null  object
#  5   Sentiment        22524 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.0+ MB

# %%
data.describe()                      #statistical summary of data
# Out:
#          Unnamed: 0  Number of Likes
# count  22524.000000     22524.000000
# mean   11261.500000        23.822856
# std     6502.263068      2128.018705
# min        0.000000         0.000000
# 25%     5630.750000         0.000000
# 50%    11261.500000         0.000000
# 75%    16892.250000         2.000000
# max    22523.000000    316867.000000

# %%
data.describe(include='all')                           #gives both categorical & continuous data
# Out:
#           Unnamed: 0               Date Created  Number of Likes  \
# count   22524.000000                      22524     22524.000000
# unique           NaN                      14412              NaN
# top              NaN  2022-11-20 16:10:10+00:00              NaN
# freq             NaN                         24              NaN
# mean    11261.500000                        NaN        23.822856
# std      6502.263068                        NaN      2128.018705
# min         0.000000                        NaN         0.000000
# 25%      5630.750000                        NaN         0.000000
# 50%     11261.500000                        NaN         0.000000
# 75%     16892.250000                        NaN         2.000000
# max     22523.000000                        NaN    316867.000000
#
#            Source of Tweet                                              Tweet  \
# count                22524                                              22524
# ...

# %%
data.isna().sum()               #sum the null values
# Out:
# Unnamed: 0         0
# Date Created       0
# Number of Likes    0
# Source of Tweet    0
# Tweet              0
# Sentiment          0
# dtype: int64

# %%
# Subsetting / Extracting Rows
df=data[2:17]
df
# Out:
#     Unnamed: 0               Date Created  Number of Likes  \
# 2            2  2022-11-20 23:58:41+00:00                1
# 3            3  2022-11-20 23:58:33+00:00                1
# 4            4  2022-11-20 23:58:28+00:00                0
# 5            5  2022-11-20 23:57:32+00:00                0
# 6            6  2022-11-20 23:57:06+00:00                0
# 7            7  2022-11-20 23:57:05+00:00                0
# 8            8  2022-11-20 23:56:10+00:00                1
# 9            9  2022-11-20 23:56:08+00:00                0
# 10          10  2022-11-20 23:56:05+00:00                1
# 11          11  2022-11-20 23:54:44+00:00                0
# 12          12  2022-11-20 23:54:31+00:00                0
# 13          13  2022-11-20 23:54:12+00:00                5
# 14          14  2022-11-20 23:53:52+00:00                0
# 15          15  2022-11-20 23:53:44+00:00                1
# 16          16  2022-11-20 23:53:27+00:00                0
#
# ...

# %%
df[["Tweet"]]                         #extracting the column
# Out:
#                                                 Tweet
# 2   Worth reading while watching #WorldCup2022 htt...
# 3   Golden Maknae shinning bright\n\nhttps://t.co/...
# 4   If the BBC cares so much about human rights, h...
# 5   And like, will the mexican fans be able to scr...
# 6   Look like a only me and the Jamaican football ...
# 7   Really? Football on a Monday morning at 9 and ...
# 8   As the World Cup starts in Qatar, it’s Black A...
# 9   #WorldCup2022 @ITVSport &amp; @LFSYSTEMMUSIC g...
# 10  #Qatar tried to help its useless soccer team 5...
# 11  What a happy night @socios @Socios_Turkiye \n#...
# 12              Let’s go #TeamUSA 🇺🇸🇺🇸🇺🇸#WorldCup2022
# 13  Tyler Adams will have a CAPTAIN moment this #W...
# 14  This is a good and promising project.should al...
# 15  What is your World Cup prediction? We have 🇩🇪 ...
# 16  RT @Quicktake Qatari officials are set to ban ...

# %%
df1=df[["Date Created","Source of Tweet","Number of Likes","Tweet","Sentiment"]]
df1
# Out:
#                  Date Created      Source of Tweet  Number of Likes  \
# 2   2022-11-20 23:58:41+00:00   Twitter for iPhone                1
# 3   2022-11-20 23:58:33+00:00      Twitter Web App                1
# 4   2022-11-20 23:58:28+00:00  Twitter for Android                0
# 5   2022-11-20 23:57:32+00:00  Twitter for Android                0
# 6   2022-11-20 23:57:06+00:00  Twitter for Android                0
# 7   2022-11-20 23:57:05+00:00  Twitter for Android                0
# 8   2022-11-20 23:56:10+00:00   Twitter for iPhone                1
# 9   2022-11-20 23:56:08+00:00   Twitter for iPhone                0
# 10  2022-11-20 23:56:05+00:00   Twitter for iPhone                1
# 11  2022-11-20 23:54:44+00:00   Twitter for iPhone                0
# 12  2022-11-20 23:54:31+00:00   Twitter for iPhone                0
# 13  2022-11-20 23:54:12+00:00   Twitter for iPhone                5
# 14  2022-11-20 23:53:52+00:00      Twitter Web App                0
# ...

# %%
# needs both rows and columns on index subsetting (R,C format)
# index based subsetting(iloc)
df1.iloc[2:5,3:5]
# Out:
#                                                Tweet Sentiment
# 4  If the BBC cares so much about human rights, h...  negative
# 5  And like, will the mexican fans be able to scr...  negative
# 6  Look like a only me and the Jamaican football ...   neutral

# %%
df2=df1.iloc[:,1:6]
df2
# Out:
#         Source of Tweet  Number of Likes  \
# 2    Twitter for iPhone                1
# 3       Twitter Web App                1
# 4   Twitter for Android                0
# 5   Twitter for Android                0
# 6   Twitter for Android                0
# 7   Twitter for Android                0
# 8    Twitter for iPhone                1
# 9    Twitter for iPhone                0
# 10   Twitter for iPhone                1
# 11   Twitter for iPhone                0
# 12   Twitter for iPhone                0
# 13   Twitter for iPhone                5
# 14      Twitter Web App                0
# 15   Twitter for iPhone                1
# 16                IFTTT                0
#
#                                                 Tweet Sentiment
# 2   Worth reading while watching #WorldCup2022 htt...  positive
# 3   Golden Maknae shinning bright\n\nhttps://t.co/...  positive
# 4   If the BBC cares so much about human rights, h...  negative
# ...

# %%
df2=df1.loc[:,["Source of Tweet","Number of Likes","Tweet","Sentiment"]]                 #value based subsetting
df2
# Out:
#         Source of Tweet  Number of Likes  \
# 2    Twitter for iPhone                1
# 3       Twitter Web App                1
# 4   Twitter for Android                0
# 5   Twitter for Android                0
# 6   Twitter for Android                0
# 7   Twitter for Android                0
# 8    Twitter for iPhone                1
# 9    Twitter for iPhone                0
# 10   Twitter for iPhone                1
# 11   Twitter for iPhone                0
# 12   Twitter for iPhone                0
# 13   Twitter for iPhone                5
# 14      Twitter Web App                0
# 15   Twitter for iPhone                1
# 16                IFTTT                0
#
#                                                 Tweet Sentiment
# 2   Worth reading while watching #WorldCup2022 htt...  positive
# 3   Golden Maknae shinning bright\n\nhttps://t.co/...  positive
# 4   If the BBC cares so much about human rights, h...  negative
# ...

# %%
df[df["Number of Likes"]>2]
# Out:
#     Unnamed: 0               Date Created  Number of Likes  \
# 13          13  2022-11-20 23:54:12+00:00                5
#
#        Source of Tweet                                              Tweet  \
# 13  Twitter for iPhone  Tyler Adams will have a CAPTAIN moment this #W...
#
#    Sentiment
# 13  positive

# %%
df.columns                    #Accessing columns
# Out:
# Index(['Unnamed: 0', 'Date Created', 'Number of Likes', 'Source of Tweet',
#        'Tweet', 'Sentiment'],
#       dtype='object')

# %%
df3=df2.rename(columns={"Sentiment":"Response","Number of Likes":'Number of Likes each day'})                #sentiment renamed as Response
df3
# Out:
#         Source of Tweet  Number of Likes each day  \
# 2    Twitter for iPhone                         1
# 3       Twitter Web App                         1
# 4   Twitter for Android                         0
# 5   Twitter for Android                         0
# 6   Twitter for Android                         0
# 7   Twitter for Android                         0
# 8    Twitter for iPhone                         1
# 9    Twitter for iPhone                         0
# 10   Twitter for iPhone                         1
# 11   Twitter for iPhone                         0
# 12   Twitter for iPhone                         0
# 13   Twitter for iPhone                         5
# 14      Twitter Web App                         0
# 15   Twitter for iPhone                         1
# 16                IFTTT                         0
#
#                                                 Tweet  Response
# 2   Worth reading while watching #WorldCup2022 htt...  positive
# ...

# %%
df3[["No. of likes per week"]]=df3[["Number of Likes each day"]]*10
df3[["No. of likes per week"]]
# Out:
#     No. of likes per week
# 2                      10
# 3                      10
# 4                       0
# 5                       0
# 6                       0
# 7                       0
# 8                      10
# 9                       0
# 10                     10
# 11                      0
# 12                      0
# 13                     50
# 14                      0
# 15                     10
# 16                      0

# %%
df3_copy=df3.copy()                           
df3_copy
# Out:
#         Source of Tweet  Number of Likes each day  \
# 2    Twitter for iPhone                         1
# 3       Twitter Web App                         1
# 4   Twitter for Android                         0
# 5   Twitter for Android                         0
# 6   Twitter for Android                         0
# 7   Twitter for Android                         0
# 8    Twitter for iPhone                         1
# 9    Twitter for iPhone                         0
# 10   Twitter for iPhone                         1
# 11   Twitter for iPhone                         0
# 12   Twitter for iPhone                         0
# 13   Twitter for iPhone                         5
# 14      Twitter Web App                         0
# 15   Twitter for iPhone                         1
#
#                                                 Tweet  Response  \
# 2   Worth reading while watching #WorldCup2022 htt...  positive
# 3   Golden Maknae shinning bright\n\nhttps://t.co/...  positive
# ...

# %%
mask=df3_copy["No. of likes per week"]!=0                                  #not equal to '0'
df3_copy[mask]
# Out:
#        Source of Tweet  Number of Likes each day  \
# 2   Twitter for iPhone                         1
# 3      Twitter Web App                         1
# 8   Twitter for iPhone                         1
# 10  Twitter for iPhone                         1
# 13  Twitter for iPhone                         5
# 15  Twitter for iPhone                         1
#
#                                                 Tweet  Response  \
# 2   Worth reading while watching #WorldCup2022 htt...  positive
# 3   Golden Maknae shinning bright\n\nhttps://t.co/...  positive
# 8   As the World Cup starts in Qatar, it’s Black A...  positive
# 10  #Qatar tried to help its useless soccer team 5...  negative
# 13  Tyler Adams will have a CAPTAIN moment this #W...  positive
# 15  What is your World Cup prediction? We have 🇩🇪 ...   neutral
#
#     No. of likes per week
# 2                      10
# 3                      10
# 8                      10
# 10                     10
# 13                     50
# ...

# %%
sns.set_theme()

# %%
# Correlation -- 
corrDf=df3_copy.corr()
corrDf.head()
# Out:
#                           Number of Likes each day  No. of likes per week
# Number of Likes each day                       1.0                    1.0
# No. of likes per week                          1.0                    1.0

# %%
sns.heatmap(corrDf)
# Out:
# <AxesSubplot:>
